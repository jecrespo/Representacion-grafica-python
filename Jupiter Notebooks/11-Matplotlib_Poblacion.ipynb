# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: MacOSX

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
url = 'https://python-graph-gallery.com/wp-content/uploads/gapminderData.csv'
data = pd.read_csv(url)

# %%
data
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
data.describe()
# Out:
#              year           pop      lifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165877
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846989
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
data.head(25)
# Out:
#         country  year         pop continent  lifeExp    gdpPercap
# 0   Afghanistan  1952   8425333.0      Asia   28.801   779.445314
# 1   Afghanistan  1957   9240934.0      Asia   30.332   820.853030
# 2   Afghanistan  1962  10267083.0      Asia   31.997   853.100710
# 3   Afghanistan  1967  11537966.0      Asia   34.020   836.197138
# 4   Afghanistan  1972  13079460.0      Asia   36.088   739.981106
# 5   Afghanistan  1977  14880372.0      Asia   38.438   786.113360
# 6   Afghanistan  1982  12881816.0      Asia   39.854   978.011439
# 7   Afghanistan  1987  13867957.0      Asia   40.822   852.395945
# 8   Afghanistan  1992  16317921.0      Asia   41.674   649.341395
# 9   Afghanistan  1997  22227415.0      Asia   41.763   635.341351
# 10  Afghanistan  2002  25268405.0      Asia   42.129   726.734055
# 11  Afghanistan  2007  31889923.0      Asia   43.828   974.580338
# 12      Albania  1952   1282697.0    Europe   55.230  1601.056136
# ...

# %%
data.year.describe()
# Out:
# count    1704.00000
# mean     1979.50000
# std        17.26533
# min      1952.00000
# 25%      1965.75000
# 50%      1979.50000
# 75%      1993.25000
# max      2007.00000
# Name: year, dtype: float64

# %% [markdown]
# # elegimos los datos de 1982

# %%
data82 = data[data.year==1982]

# %%
data82
# Out:
#                  country  year         pop continent  lifeExp    gdpPercap
# 6            Afghanistan  1982  12881816.0      Asia   39.854   978.011439
# 18               Albania  1982   2780097.0    Europe   70.420  3630.880722
# 30               Algeria  1982  20033753.0    Africa   61.368  5745.160213
# 42                Angola  1982   7016384.0    Africa   39.942  2756.953672
# 54             Argentina  1982  29341374.0  Americas   69.942  8997.897412
# ...                  ...   ...         ...       ...      ...          ...
# 1650             Vietnam  1982  56142181.0      Asia   58.816   707.235786
# 1662  West Bank and Gaza  1982   1425876.0      Asia   64.406  4336.032082
# 1674         Yemen, Rep.  1982   9657618.0      Asia   49.113  1977.557010
# 1686              Zambia  1982   6100407.0    Africa   51.821  1408.678565
# 1698            Zimbabwe  1982   7636524.0    Africa   60.363   788.855041
#
# [142 rows x 6 columns]

# %%
plt.figure()
data82['continent'] = pd.Categorical(data82['continent'])
plt.scatter(data82.lifeExp,
           data82.gdpPercap,
           s=data82['pop']/200000,
           c=data82.continent.cat.codes)
# Out:
# /anaconda3/envs/python37/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.continent.cat.categories
# Out:
# Index(['Africa', 'Americas', 'Asia', 'Europe', 'Oceania'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# year         1704 non-null int64
# pop          1704 non-null float64
# continent    1704 non-null object
# lifeExp      1704 non-null float64
# gdpPercap    1704 non-null float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %%
data.continent.cat.codes
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1699    0
# 1700    0
# 1701    0
# 1702    0
# 1703    0
# Length: 1704, dtype: int8

# %%
data_country = data[data.country=='Spain']
plt.figure()
data_country['continent'] = pd.Categorical(data_country['year'])
plt.scatter(data_country.lifeExp,
           data_country.gdpPercap,
           s=data_country['pop']/20000,
           c=data_country.year)
plt.colorbar()
# Out:
# /anaconda3/envs/python37/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data_country
# Out:
#      country  year         pop continent  lifeExp     gdpPercap
# 1416   Spain  1952  28549870.0      1952   64.940   3834.034742
# 1417   Spain  1957  29841614.0      1957   66.660   4564.802410
# 1418   Spain  1962  31158061.0      1962   69.690   5693.843879
# 1419   Spain  1967  32850275.0      1967   71.440   7993.512294
# 1420   Spain  1972  34513161.0      1972   73.060  10638.751310
# 1421   Spain  1977  36439000.0      1977   74.390  13236.921170
# 1422   Spain  1982  37983310.0      1982   76.300  13926.169970
# 1423   Spain  1987  38880702.0      1987   76.900  15764.983130
# 1424   Spain  1992  39549438.0      1992   77.570  18603.064520
# 1425   Spain  1997  39855442.0      1997   78.770  20445.298960
# 1426   Spain  2002  40152517.0      2002   79.780  24835.471660
# 1427   Spain  2007  40448191.0      2007   80.941  28821.063700

# %% [markdown]
# # grafico de 4 dimensiones, se podría añadir una quinta con el nivel de transparencia
# * renta per capita
# * esperanza de vida
# * población
# * año
