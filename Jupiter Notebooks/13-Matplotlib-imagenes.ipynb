# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: MacOSX

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.image as mpimage

# %%
img = mpimage.imread('Zebra.jpg')
plt.figure()
plt.imshow(img)
plt.title('Zebra')
# Out:
# Text(0.5, 1.0, 'Zebra')

# %%
img.shape
# Out:
# (1328, 1992, 3)

# %%
plt.figure()
rojo = img[:,:,0]
plt.imshow(rojo)

# %%
img
# Out:
# array([[[205, 183, 146],
#         [205, 183, 146],
#         [206, 184, 147],
#         ...,
#         [197, 175, 136],
#         [199, 175, 137],
#         [199, 175, 139]],
#
#        [[206, 182, 144],
#         [207, 183, 145],
#         [208, 184, 146],
#         ...,
#         [197, 175, 138],
#         [199, 175, 139],
#         [199, 175, 139]],
#
#        [[208, 185, 144],
#         [206, 183, 142],
#         [208, 185, 144],
#         ...,
#         [199, 175, 139],
#         [200, 176, 140],
#         [199, 175, 139]],
#
#        ...,
#
#        [[155, 141, 102],
#         [152, 139,  97],
#         [152, 139,  95],
#         ...,
#         [176, 153, 121],
#         [187, 168, 136],
#         [189, 173, 140]],
#
#        [[154, 142, 102],
#         [153, 141,  99],
#         [153, 140,  96],
#         ...,
#         [177, 152, 121],
#         [185, 165, 132],
#         [184, 166, 130]],
#
#        [[154, 145, 106],
#         [152, 143, 102],
#         [152, 140,  98],
# ...
