# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: MacOSX

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3]

# %%
y = [5,6,7]

# %%
fig = plt.figure()
lines_1 = plt.plot(x,y,'ro--',label = "linea roja",linewidth=6)
lines_2 = plt.plot(x,[4,4,5],'go--',label = "linea verde",linewidth=6)
text_legend = plt.legend()
text_title = plt.title("ejemplos")
plt.fill()
# Out:
# []

# %%
x = np.arange(10)
y = np.arange(10)
fig = plt.figure()
lines_1 = plt.plot(x,y,'ro--',label = "linea roja",linewidth=6)
text_legend = plt.legend()
text_title = plt.title("ejemplos")

# %%
import datetime

# %%
hoy = datetime.datetime.now()

# %%
hoy
# Out:
# datetime.datetime(2019, 9, 17, 18, 11, 16, 227986)
