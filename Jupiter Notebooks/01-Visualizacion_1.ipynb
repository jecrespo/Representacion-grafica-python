# %% [markdown]
# # Visualización con Matplotlib

# %%
print("hola")
# Out:
# hola

# %%
2+2
# Out:
# 4

# %% [markdown]
# # API Pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [2,3,4]
y = [5,7,8]

# %%
plt.plot(x,y)

# %%
x_np = np.array(x)
y_np = np.array(y)

# %%
plt.plot(x_np,y_np)

# %%
x+y
# Out:
# [2, 3, 4, 5, 7, 8]

# %%
x_np+y_np
# Out:
# array([ 7, 10, 12])

# %%
plt.plot(x_np,y_np**2)
